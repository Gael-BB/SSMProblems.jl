# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("output.csv")
df.head()
# Out:
#    seed algorithm  squared_error  effective_sample_size    runtime
# 0     1      PMMH       0.708815              15.811397   1.285769
# 1     1    PGIBBS       0.573429               9.078319   2.108501
# 2     1      EHMM       0.674214               7.117245   1.080969
# 3     2      PMMH       0.007153               5.428312  81.712064
# 4     2    PGIBBS       0.643627              15.281634   0.540357

# %%
df.shape
# Out:
# (15, 5)
