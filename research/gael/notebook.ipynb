# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("output.csv")
df.head()
# Out:
#    seed  ground_truth_posterior algorithm  squared_error  \
# 0     1               -0.025341      PMMH       0.002538
# 1     1               -0.025341    PGIBBS       0.000589
# 2     1               -0.025341      EHMM       0.000059
# 3     2                0.990116      PMMH       0.000025
# 4     2                0.990116    PGIBBS       0.000159
#
#    effective_sample_size   runtime
# 0               6.773417  1.697862
# 1             790.676632  1.715199
# 2             719.223888  0.981370
# 3             195.601227  0.361556
# 4             190.288304  0.464304

# %%
df.shape
# Out:
# (15, 6)
